# %%
import pandas as pd
import numpy  as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from tensorflow import keras
from keras.layers import Dense, LSTM

# %%
scaler = RobustScaler()

train_data = pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/test.csv")

print(train_data.head())
# Out:
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
pressure_targets = train_data[['pressure']].to_numpy().reshape(-1, 80)

train_data = train_data.drop(['pressure', 'id', 'breath_id'], axis=1)
test_data = test_data.drop(['id', 'breath_id'], axis=1)

print(train_data.shape, test_data.shape, pressure_targets.shape)
# Out:
# (6036000, 5) (4024000, 5) (75450, 80)

# %%
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

print(train_data[:5])
# Out:
# [[ 0.          0.75       -0.98905216 -0.93738445 -1.        ]
#  [ 0.          0.75       -0.96360815  3.04927811 -1.        ]
#  [ 0.          0.75       -0.93800551  3.94819476 -1.        ]
#  [ 0.          0.75       -0.91227758  4.0134517  -1.        ]
#  [ 0.          0.75       -0.88640941  4.56833168 -1.        ]]

# %%
features = train_data.shape[-1]

train_data = train_data.reshape(-1, 80, features)
test_data = test_data.reshape(-1, 80, features)

print(train_data.shape, test_data.shape)
# Out:
# (75450, 80, 5) (50300, 80, 5)

# %%
def plot_history(history):
    plt.plot(history.history['mse'])
    plt.plot(history.history['val_mse'])
    plt.title('model mse')
    plt.ylabel('mse')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
kfold_splits = 4
kfold = KFold(n_splits=kfold_splits, shuffle=False)

test_predictions = []

for fold, (train_index, test_index) in enumerate(kfold.split(train_data, pressure_targets)):
    print(f"\nfold {fold}\n")

    x_train, x_valid = train_data[train_index], train_data[test_index]
    y_train, y_valid = pressure_targets[train_index], pressure_targets[test_index]
    
    print(x_train.shape, y_train.shape)
    print(x_valid.shape, y_valid.shape)

    model = keras.models.Sequential()
    
    model.add(LSTM(250, return_sequences=True, input_shape=(80, features)))
    model.add(Dense(250))
    model.add(Dense(1))
    
    #model.summary()
    
    model.compile(
        loss='mse', 
        optimizer='adam', 
        metrics=['mse'])
    
    history = model.fit(x_train, y_train, 
                        validation_data=(x_valid, y_valid), 
                        epochs=5, 
                        batch_size=1000)
    
    model.save(f'models/fold-{fold}.h5')
    plot_history(history)
    
    
    test_predictions.append(model.predict(test_data))
# Out:
# fold 0
#
# (56587, 80, 5) (56587, 80)
# (18863, 80, 5) (18863, 80)
# Epoch 1/5
# 57/57 [==============================] - 6s 42ms/step - loss: 40.0808 - mse: 40.0808 - val_loss: 17.1842 - val_mse: 17.1842
# Epoch 2/5
# 57/57 [==============================] - 2s 36ms/step - loss: 12.5811 - mse: 12.5811 - val_loss: 8.7628 - val_mse: 8.7628
# Epoch 3/5
# 57/57 [==============================] - 2s 36ms/step - loss: 8.3894 - mse: 8.3894 - val_loss: 6.3810 - val_mse: 6.3810
# Epoch 4/5
# 57/57 [==============================] - 2s 36ms/step - loss: 5.4671 - mse: 5.4671 - val_loss: 4.3878 - val_mse: 4.3878
# Epoch 5/5
# 57/57 [==============================] - 2s 37ms/step - loss: 4.1188 - mse: 4.1188 - val_loss: 3.8884 - val_mse: 3.8884
# fold 1
#
# (56587, 80, 5) (56587, 80)
# (18863, 80, 5) (18863, 80)
# Epoch 1/5
# 57/57 [==============================] - 4s 43ms/step - loss: 39.2327 - mse: 39.2327 - val_loss: 16.2907 - val_mse: 16.2907
# Epoch 2/5
# 57/57 [==============================] - 2s 36ms/step - loss: 11.5571 - mse: 11.5571 - val_loss: 7.9714 - val_mse: 7.9714
# Epoch 3/5
# 57/57 [==============================] - 2s 36ms/step - loss: 6.7496 - mse: 6.7496 - val_loss: 6.7681 - val_mse: 6.7681
# Epoch 4/5
# 57/57 [==============================] - 2s 36ms/step - loss: 4.5808 - mse: 4.5808 - val_loss: 4.1579 - val_mse: 4.1579
# Epoch 5/5
# 57/57 [==============================] - 2s 37ms/step - loss: 4.1429 - mse: 4.1429 - val_loss: 3.6297 - val_mse: 3.6297
# fold 2
#
# (56588, 80, 5) (56588, 80)
# (18862, 80, 5) (18862, 80)
# Epoch 1/5
# 57/57 [==============================] - 4s 44ms/step - loss: 41.3714 - mse: 41.3714 - val_loss: 18.1145 - val_mse: 18.1145
# Epoch 2/5
# 57/57 [==============================] - 2s 36ms/step - loss: 13.8166 - mse: 13.8166 - val_loss: 9.7089 - val_mse: 9.7089
# Epoch 3/5
# 57/57 [==============================] - 2s 37ms/step - loss: 7.7921 - mse: 7.7921 - val_loss: 5.9101 - val_mse: 5.9101
# Epoch 4/5
# 57/57 [==============================] - 2s 38ms/step - loss: 5.2746 - mse: 5.2746 - val_loss: 4.7622 - val_mse: 4.7622
# Epoch 5/5
# 57/57 [==============================] - 2s 36ms/step - loss: 4.0965 - mse: 4.0965 - val_loss: 3.7594 - val_mse: 3.7594
# fold 3
#
# (56588, 80, 5) (56588, 80)
# (18862, 80, 5) (18862, 80)
# Epoch 1/5
# 57/57 [==============================] - 4s 42ms/step - loss: 38.9661 - mse: 38.9661 - val_loss: 15.4648 - val_mse: 15.4648
# Epoch 2/5
# 57/57 [==============================] - 2s 36ms/step - loss: 12.1129 - mse: 12.1129 - val_loss: 8.6097 - val_mse: 8.6097
# Epoch 3/5
# 57/57 [==============================] - 2s 36ms/step - loss: 7.2581 - mse: 7.2581 - val_loss: 6.0395 - val_mse: 6.0395
# Epoch 4/5
# 57/57 [==============================] - 2s 37ms/step - loss: 5.0297 - mse: 5.0297 - val_loss: 4.1341 - val_mse: 4.1341
# Epoch 5/5
# 57/57 [==============================] - 2s 37ms/step - loss: 4.0052 - mse: 4.0052 - val_loss: 3.3513 - val_mse: 3.3513

# %%
pressure_predictions = model.predict(x_valid)

plot_pressure_targets = pressure_predictions.reshape(1, 1508960)
plot_y_valid = y_valid.reshape(1, 1508960)

# %%
plt.plot(plot_pressure_targets[0, :2000])
plt.plot(plot_y_valid[0, :2000])

plt.title('model')
plt.ylabel('pressure')
plt.xlabel('time')
plt.legend(['predicted', 'expected'], loc='upper left')
plt.show()

# %%
submission = pd.read_csv("data/sample_submission.csv")
# Out:
#    id  pressure
# 0   1         0
# 1   2         0
# 2   3         0
# 3   4         0
# 4   5         0
